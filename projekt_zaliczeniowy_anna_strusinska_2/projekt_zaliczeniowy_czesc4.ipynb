# %%
#	Wykorzystując pakiet matplotlib wykonaj wykres ilustrujący liczbę tweetów per dzień tygodnia

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
MAIN_DATA = pd.read_csv("/content/dane8.csv")

# %%
df_twitter = MAIN_DATA.copy()

# %%
df_twitter
# Out:
#       coordinates                      created_at  \
# 0             NaN  Thu Dec 01 15:29:44 +0000 2022
# 1             NaN  Thu Dec 01 13:28:05 +0000 2022
# 2             NaN  Thu Dec 01 13:31:57 +0000 2022
# 3             NaN  Thu Dec 01 16:41:52 +0000 2022
# 4             NaN  Thu Dec 01 15:54:40 +0000 2022
# ...           ...                             ...
# 3584          NaN  Wed Nov 23 08:04:58 +0000 2022
# 3585          NaN  Wed Nov 23 08:02:01 +0000 2022
# 3586          NaN  Wed Nov 23 07:51:59 +0000 2022
# 3587          NaN  Wed Nov 23 02:47:47 +0000 2022
# 3588          NaN  Wed Nov 23 04:56:35 +0000 2022
#
#                            hashtags media  \
# 0                               NaN   NaN
# 1                               NaN   NaN
# 2                               NaN   NaN
# 3                               NaN   NaN
# 4                               NaN   NaN
# ...                             ...   ...
# 3584                            NaN   NaN
# ...

# %%
tweets_per_day = df_twitter["created_at"].str[:3].value_counts()
print(tweets_per_day)
# Out:
# created_at
# Thu    763
# Wed    758
# Tue    572
# Mon    502
# Fri    442
# Sat    329
# Sun    223
# Name: count, dtype: int64

# %%
fig, ax = plt.subplots()

dni_tygodnia = ["Poniedziałek", "Wtorek", "Środa", "Czwartek", "Piątek", "Sobota", "Niedziela"]
counts = [502, 572, 758, 763, 442, 329, 223]
bar_color = "tab:pink"

ax.bar(dni_tygodnia, counts, color=bar_color)

ax.set_ylabel("Liczba tweetów")
ax.set_title("Dzień tygodnia")

plt.show()
